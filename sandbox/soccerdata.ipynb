# %% [markdown]
# ## 1. Search on perplexity some ideas
# ## 2. Get data (test new library)

# %%
import soccerdata as sd

understat = sd.Understat(leagues="ENG-Premier League", seasons="2025/2026")
print(understat.__doc__)
# Out:
# [02/17/26 19:46:18] INFO     No custom team name replacements found. You can configure these in       ]8;id=248502;file://c:\Users\david\Documents\Courses\football-match-prediction-nn\.venv\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=669131;file://c:\Users\david\Documents\Courses\football-match-prediction-nn\.venv\Lib\site-packages\soccerdata\_config.py#92\92]8;;\
#                              C:\Users\david\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=921855;file://c:\Users\david\Documents\Courses\football-match-prediction-nn\.venv\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=298066;file://c:\Users\david\Documents\Courses\football-match-prediction-nn\.venv\Lib\site-packages\soccerdata\_config.py#198\198]8;;\
#                              C:\Users\david\soccerdata\config\league_dict.json.
# ...

# %%
team_match_stats = understat.read_team_match_stats()
team_match_stats.head()
# Out:
#                                                                   league_id  \
# league             season game
# ENG-Premier League 2526   2025-08-15 Liverpool-Bournemouth                1
#                           2025-08-16 Aston Villa-Newcastle United         1
#                           2025-08-16 Brighton-Fulham                      1
#                           2025-08-16 Sunderland-West Ham                  1
#                           2025-08-16 Tottenham-Burnley                    1
#
#                                                                    season_id  \
# league             season game
# ENG-Premier League 2526   2025-08-15 Liverpool-Bournemouth              2025
#                           2025-08-16 Aston Villa-Newcastle United       2025
#                           2025-08-16 Brighton-Fulham                    2025
#                           2025-08-16 Sunderland-West Ham                2025
# ...
