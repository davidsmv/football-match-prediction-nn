# %%
# Out:
# (420, 11)
#    week  day        date          time               home score         away  \
# 0   1.0  Fri  2024-08-16  20:00(14:00)     Manchester Utd   1–0       Fulham
# 1   1.0  Sat  2024-08-17  12:30(06:30)       Ipswich Town   0–2    Liverpool
# 2   1.0  Sat  2024-08-17  15:00(09:00)   Newcastle United   1–0  Southampton
# 3   1.0  Sat  2024-08-17  15:00(09:00)            Everton   0–3     Brighton
# 4   1.0  Sat  2024-08-17  15:00(09:00)  Nottingham Forest   1–1  Bournemouth
#
#    attendance                 venue         referee  \
# 0     73297.0          Old Trafford    Robert Jones
# 1     30014.0  Portman Road Stadium    Tim Robinson
# 2     52196.0        St James' Park    Craig Pawson
# 3     39217.0         Goodison Park    Simon Hooper
# 4     29763.0       The City Ground  Michael Oliver
#
#                                         match_report
# 0  https://fbref.com/en/matches/cc5b4244/Manchest...
# 1  https://fbref.com/en/matches/a1d0d529/Ipswich-...
# ...
